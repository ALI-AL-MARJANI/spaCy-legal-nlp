# %% [markdown]
# ## Evaluation Notebook - Legal NLP Assistant
#
# ### This notebook evaluates the pipeline trained for:
# ### - clause classification (textcat)
# ### - legal NER (entities)
# ### - custom risk scoring
#
# ### It loads the trained model, runs predictions on the dev set, and visualizes outputs to better understand model behavior

# %%
import spacy
from spacy.tokens import DocBin
from pathlib import Path
import pandas as pd
from spacy import displacy
from pathlib import Path
